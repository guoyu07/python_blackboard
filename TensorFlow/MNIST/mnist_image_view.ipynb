# %%
import mnist_image_render as mir

test_image = "../../MNIST_data/t10k-images-idx3-ubyte.gz"
train_image = "../../MNIST_data/train-images-idx3-ubyte.gz"

test_image_data = mir.read_image(test_image)   
train_image_data = mir.read_image(train_image)   

mir.print_ndarray(test_image_data)
mir.print_ndarray(train_image_data)
# Out:
# ndim=3 size=7840000 shape=(10000, 28, 28)
# ndim=3 size=47040000 shape=(60000, 28, 28)

# %%
mir.render_full_images(test_image_data[:100])
# Out:
# <PIL.Image.Image image mode=RGB size=700x112 at 0x7F4240306510>

# %%
mir.render_full_images(train_image_data[:350], False, 35)
# Out:
# <PIL.Image.Image image mode=RGB size=980x280 at 0x7F421B300650>

# %%
mir.render_images(train_image_data[:5])
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x7F421B300510>
# <PIL.Image.Image image mode=L size=28x28 at 0x7F421B300510>
# <PIL.Image.Image image mode=L size=28x28 at 0x7F421B300510>
# <PIL.Image.Image image mode=L size=28x28 at 0x7F421B300510>
# <PIL.Image.Image image mode=L size=28x28 at 0x7F421B300510>
